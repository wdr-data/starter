# %% [markdown]
# # Wie divers ist die Oper in NRW?

# %% [markdown]
# ## Fragen
#
# - Meistgespielte Stücke
# - Meistgespielte Komponisten
# - Ätester / Jüngster Komponist
# - Männlich / Weiblich
# - Häuser im Vergleich
#     - Gesamtzahl der Aufführungen
#     - Alter
#     - Wer hat die meisten Premieren / Wiederaufführungen
# - Anzahl der Aufführungen / Alter der Komponisten (Junge werden nur 1 mal gespielt)
# -

# %%
import pandas as pd
import wptools
import wikidata
import wikipedia
import numpy as np
import requests
import json

import matplotlib.pyplot as plt
import seaborn

pd.options.display.max_rows = 999
pd.options.display.max_colwidth = 1000

# %matplotlib inline

# %%
df = pd.read_csv('opern_nrw_18_19.csv')

# %%
df.sample()
# Out:
#        Spielstätte    Ort    Titel  Anzahl       Komponist   Komponist_ber  \
# 130  Theater Hagen  Hagen  Rusalka      10  Antonín Dvořák  Antonín Dvořák
#
#       Geburtsort Geschlecht               Geburtsdatum  Geburtsjahr  Alter  \
# 130  Nelahozeves   männlich  1841-09-08 00:00:00+00:00         1841    178
#
#      Sterbedatum Verstorben        Art Bemerkung
# 130         1904        Tot  premieren       NaN

# %%
df.shape
# Out:
# (159, 15)

# %%
df.sample()
# Out:
#                               Spielstätte            Ort      Titel  Anzahl  \
# 98  Musiktheater im Revier, Gelsenkirchen  Gelsenkirchen  Mahagonny       8
#
#      Komponist Komponist_ber Geburtsort Geschlecht               Geburtsdatum  \
# 98  Kurt Weill    Kurt Weill     Dessau   männlich  1900-03-02 00:00:00+00:00
#
#     Geburtsjahr  Alter  Sterbedatum Verstorben        Art Bemerkung
# 98         1900    119         1950        Tot  premieren       NaN

# %%
df.columns
# Out:
# Index(['Spielstätte', 'Ort', 'Titel', 'Anzahl', 'Komponist', 'Komponist_ber',
#        'Geburtsort', 'Geschlecht', 'Geburtsdatum', 'Geburtsjahr', 'Alter',
#        'Sterbedatum', 'Verstorben', 'Art', 'Bemerkung'],
#       dtype='object')

# %%
df = df[['Spielstätte', 'Ort', 'Titel', 'Anzahl', 'Komponist', 'Komponist_ber',
       'Geburtsort', 'Geschlecht', 'Geburtsjahr', 'Alter',
       'Sterbedatum', 'Verstorben', 'Art', 'Bemerkung']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 14 columns):
# Spielstätte      159 non-null object
# Ort              159 non-null object
# Titel            159 non-null object
# Anzahl           159 non-null int64
# Komponist        145 non-null object
# Komponist_ber    159 non-null object
# Geburtsort       158 non-null object
# Geschlecht       159 non-null object
# Geburtsjahr      159 non-null int64
# Alter            159 non-null int64
# Sterbedatum      159 non-null int64
# Verstorben       159 non-null object
# Art              159 non-null object
# Bemerkung        17 non-null object
# dtypes: int64(4), object(10)
# memory usage: 17.5+ KB

# %%
df.Anzahl.sum()
# Out:
# 1024

# %%
len(df.Titel.unique())
# Out:
# 116

# %% [markdown]
# ### Stücke

# %%
stücke = df[['Titel', 'Anzahl']]

# %% [markdown]
# Stücke nach Titel gezählt: An wie vielen verschiedenen Häusern wurde die Zauberflöte gespielt?

# %%
stücke_count = pd.pivot_table(stücke, index=['Titel'], aggfunc='count').sort_values('Anzahl', ascending=False).head(7)
stücke_count
# Out:
#                    Anzahl
# Titel
# Die Zauberflöte         7
# Hänsel und Gretel       6
# Tosca                   5
# La Traviata             3
# Nabucco                 3
# Don Giovanni            3
# Otello                  3

# %%
stücke_count = stücke_count.sort_values('Anzahl')

# %%
stücke_count.plot(kind='barh', 
                 title='Zählt man die Inszenierungen, dann liegt \ndie Zauberflöte vor Hänsel und Gretel',
                 color='blue',
                  legend=None
                 )

# %%
plt.savefig('./img/stücke_count.png')

# %% [markdown]
# Wo überall wurde die Zauberflöte gespielt?

# %%
df.sample()
# Out:
#                 Spielstätte                  Ort   Titel  Anzahl  \
# 112  Deutsche Oper am Rhein  Düsseldorf/Duisburg  Otello       5
#
#           Komponist   Komponist_ber  Geburtsort Geschlecht  Geburtsjahr  \
# 112  Giuseppe Verdi  Giuseppe Verdi  Le Roncole   männlich         1813
#
#      Alter  Sterbedatum Verstorben              Art          Bemerkung
# 112    206         1901        Tot  wiederaufnahmen  (Haus Düsseldorf)

# %%
df.groupby('Spielstätte').sum()
# Out:
#                                        Anzahl  Geburtsjahr  Alter  Sterbedatum
# Spielstätte
# Deutsche Oper am Rhein                    218        69743   6979        64192
# Musiktheater im Revier, Gelsenkirchen      75        22528   1700        19180
# Oper Köln                                 150        37128   3252        34424
# Oper, Ballett und Junge Oper Dortmund      67        17062   1109        11649
# Stadttheater Minden                         6         1813    206         1883
# Theater Aachen                             68        14548   1604        15134
# Theater Bielefeld                          46        12803   1330        11210
# Theater Hagen                              74        15975   2196        16599
# Theater Herford                             4         5540    517         5755
# Theater Krefeld Mönchengladbach            82        22228   2000        18987
# Theater und Philharmoie Essen              74        29180   3124        28181
# Theater/Oper/Schauspiel Bonn              105        23867   2380        20654
# Wuppertaler Bühnen                         55        18749   1441        15333

# %%
zauberflöte = df[df.Titel == 'Die Zauberflöte']

# %%
df.groupby('Spielstätte').sum()
# Out:
#                                        Anzahl  Geburtsjahr  Alter  Sterbedatum
# Spielstätte
# Deutsche Oper am Rhein                    218        69743   6979        64192
# Musiktheater im Revier, Gelsenkirchen      75        22528   1700        19180
# Oper Köln                                 150        37128   3252        34424
# Oper, Ballett und Junge Oper Dortmund      67        17062   1109        11649
# Stadttheater Minden                         6         1813    206         1883
# Theater Aachen                             68        14548   1604        15134
# Theater Bielefeld                          46        12803   1330        11210
# Theater Hagen                              74        15975   2196        16599
# Theater Herford                             4         5540    517         5755
# Theater Krefeld Mönchengladbach            82        22228   2000        18987
# Theater und Philharmoie Essen              74        29180   3124        28181
# Theater/Oper/Schauspiel Bonn              105        23867   2380        20654
# Wuppertaler Bühnen                         55        18749   1441        15333

# %%
zauberflöte.columns
# Out:
# Index(['Spielstätte', 'Ort', 'Titel', 'Anzahl', 'Komponist', 'Komponist_ber',
#        'Geburtsort', 'Geschlecht', 'Geburtsjahr', 'Alter', 'Sterbedatum',
#        'Verstorben', 'Art', 'Bemerkung'],
#       dtype='object')

# %%
zauberflöte = zauberflöte[['Spielstätte', 'Ort', 'Anzahl']]

# %%
zauerflöte = zauberflöte.groupby('Ort').sum()

# %%
zauberflöte.to_clipboard('./csv/01_zauberfloete.csv', sep=',', encoding='utf-8')

# %%
stücke_orte = df[['Ort', 'Titel', 'Anzahl']]

# %%
# Wo wurde welches Stück am meisten gespielt? 
stücke_orte.sort_values('Anzahl', ascending=False).head()
# Out:
#                     Ort                  Titel  Anzahl
# 39  Düsseldorf/Duisburg        Die Zauberflöte      21
# 36                 Köln            Die Walküre      17
# 16             Dortmund  Das Land des Lächelns      16
# 38                 Köln        Die Zauberflöte      15
# 74                 Köln       Im weißen Rössel      15

# %% [markdown]
# ## Anzahl der Aufführungen

# %%
stücke_anzahl = pd.pivot_table(stücke, index=['Titel'], aggfunc='sum').sort_values('Anzahl', ascending=False)
stücke_anzahl
# Out:
#                                                                       Anzahl
# Titel
# Die Zauberflöte                                                           76
# Hänsel und Gretel                                                         34
# La Traviata                                                               32
# Das Land des Lächelns                                                     26
# Rusalka                                                                   21
# Roméo et Juliette                                                         20
# La Grande-Duchesse de Géroldstein                                         19
# Die Walküre                                                               19
# Nabucco                                                                   19
# Xerxes                                                                    19
# Turandot                                                                  19
# Otello                                                                    18
# Tosca                                                                     17
# La forza del destino                                                      17
# Die Schneekönigin                                                         16
# Im weißen Rössel                                                          15
# West Side Story                                                           15
# Cosi fan tutte                                                            14
# Götterdämmerung                                                           13
# Il Turco in Italia                                                        13
# Wo die wilden Kerle wohnen                                                13
# Salome                                                                    12
# Carmen                                                                    12
# Don Giovanni                                                              12
# Lohengrin                                                                 12
# Orpheus in der Unterwelt                                                  11
# Pariser Leben                                                             11
# Play Europeras 1&2                                                        10
# Hoffmanns Erzählungen für Kinder                                          10
# Der Freischütz                                                            10
# Elektra                                                                   10
# La Cenerentola                                                            10
# Viva Verdi                                                                10
# Wassermusik und Dido and Aeneas                                           10
# Simon Boccanegra                                                          10
# Perlenfischer                                                              9
# Mass                                                                       9
# Eugen Onegin                                                               9
# Il trionfo del Tempo e del Disinganno                                      9
# Marx in London                                                             9
# Luisa Miller                                                               8
# Pique Dame                                                                 8
# Mahagonny                                                                  8
# Königskinder                                                               8
# Je suis Jacques. Eine Jubiläums-Offenbachiade von Christian von Götz       8
# Rheingold                                                                  8
# Troubel in Tahiti / A Quiet Place                                          8
# Kleines Stück Himmel                                                       8
# Die Sache Makropolus                                                       8
# Die Fledermaus                                                             8
# Die sizilianische Vesper                                                   8
# Boris Godunow                                                              8
# Die Hochzeit des Figaro                                                    7
# Die Faschingsfee                                                           7
# Petruschka / L'Enfant et les Sortilèges                                    7
# Der Räuber Hotzenplotz                                                     7
# Echnaton                                                                   7
# Hamlet                                                                     7
# Street Scene                                                               7
# Gold!                                                                      7
# Sommernachtstraum                                                          6
# Dead Man Walking                                                           6
# Maria Stuarda                                                              6
# Die Gespräche der Karmeliterinnen                                          6
# Amadis                                                                     6
# La Gioconda                                                                6
# Don Pasquale                                                               6
# Jérusalem                                                                  6
# Eine Nacht in Venedig                                                      6
# Quartett                                                                   5
# Der Ring an einem Abend                                                    5
# Ariane und Blaubart                                                        5
# Peter Grimes                                                               5
# Ariadne auf Naxos                                                          5
# Der Kaiser von Atlantis                                                    5
# Medea                                                                      5
# Tristan und Isolde                                                         5
# Die Entführung aus dem Serail                                              5
# Adam Schaf hat Angst                                                       5
# Geisterritter                                                              5
# La scuola de’ gelosi                                                       5
# Jeanne D‘Arc – Szenen aus dem Leben der Heiligen Johanna                   5
# Madama Butterfly                                                           5
# Il barbiere di Siviglia                                                    5
# Fidelio                                                                    4
# Cavalleria rusticana / Pagliacci                                           4
# Schade, dass sie eine Hure war                                             4
# Mare Nostrum                                                               4
# Aida                                                                       4
# Klein Zaches                                                               4
# Romeo und Julia                                                            4
# Don Carlo                                                                  4
# Falstaff                                                                   4
# Le nozze di Figaro                                                         4
# Der feurige Engel                                                          4
# Let´s Stop Brexit!                                                         4
# Combattimento di Trancredi e Clorinda                                      4
# Der goldene Drache                                                         4
# Schwanda der Dudelsackpfeifer                                              4
# Das Labyrinth                                                              3
# Arabella                                                                   3
# Siegfried                                                                  3
# Elegie für junge Liebende                                                  3
# Die tote Stadt                                                             3
# Rigoletto                                                                  3
# Und jetzt alle                                                             2
# Werther                                                                    2
# Das Rheingold                                                              2
# La Bohème                                                                  2
# Siegfried (Haus Düsseldorf)                                                1
# Romeo und Zeliha                                                           1
# Pin Kaiser und Fiß Husar                                                   1
# Paul Abraham - Operettenkönig von Berlin                                   1
# Ijob                                                                       1
# Die lustige Witwe                                                          1
# Martha oder der Markt zu Richmond                                          1

# %%
stücke_anzahl.hist(bins=100)

plt.savefig('./img/stuecke_anzahl_histogram.png')

# %%
stücke_anzahl.to_csv('./csv/02_stuecke_anzahl.csv')

# %%
stuecke_vs_anzahl = df[['Titel', 'Anzahl']]

# %%
stuecke_vs_anzahl = stuecke_vs_anzahl.pivot_table(index='Titel',aggfunc=['count', 'sum'])

# %%
stuecke_vs_anzahl.sort_values([('sum', 'Anzahl')], ascending=False)
# Out:
#                                                                       count  \
#                                                                      Anzahl
# Titel
# Die Zauberflöte                                                           7
# Hänsel und Gretel                                                         6
# La Traviata                                                               3
# Das Land des Lächelns                                                     2
# Rusalka                                                                   3
# Roméo et Juliette                                                         2
# La Grande-Duchesse de Géroldstein                                         2
# Die Walküre                                                               2
# Nabucco                                                                   3
# Xerxes                                                                    2
# Turandot                                                                  2
# Otello                                                                    3
# Tosca                                                                     5
# La forza del destino                                                      2
# Die Schneekönigin                                                         2
# Im weißen Rössel                                                          1
# West Side Story                                                           1
# Cosi fan tutte                                                            2
# Götterdämmerung                                                           3
# Il Turco in Italia                                                        1
# Wo die wilden Kerle wohnen                                                2
# Salome                                                                    2
# Carmen                                                                    2
# Don Giovanni                                                              3
# Lohengrin                                                                 1
# Orpheus in der Unterwelt                                                  2
# Pariser Leben                                                             1
# Play Europeras 1&2                                                        1
# Hoffmanns Erzählungen für Kinder                                          1
# Der Freischütz                                                            1
# Elektra                                                                   1
# La Cenerentola                                                            1
# Viva Verdi                                                                1
# Wassermusik und Dido and Aeneas                                           1
# Simon Boccanegra                                                          1
# Perlenfischer                                                             1
# Mass                                                                      1
# Eugen Onegin                                                              1
# Il trionfo del Tempo e del Disinganno                                     1
# Marx in London                                                            1
# Luisa Miller                                                              2
# Pique Dame                                                                1
# Mahagonny                                                                 1
# Martha oder der Markt zu Richmond                                         1

# %%
stuecke_vs_anzahl.plot.scatter(x=('sum', 'Anzahl'), y=('count', 'Anzahl'), c='DarkBlue')
plt.savefig('./img/stuecke_vs_anzahl_scatter.png')

# %%
stuecke_vs_anzahl.to_csv('./csv/03_stuecke_vs_anzahl.csv')

# %% [markdown]
# ### Komponisten

# %% [markdown]
# #### Zahl der Komponisten

# %%
composers = df[['Titel', 'Komponist_ber', 'Anzahl']]

# %%
len(set(composers.Komponist_ber))
# Out:
# 66

# %%
composers_alive = df[['Komponist_ber', 'Verstorben']]

# %%
composers_alive[composers_alive.Verstorben == 'lebt'].shape
# Out:
# (20, 2)

# %%
alive = composers_alive[composers_alive.Verstorben == 'lebt']

# %%
alive.to_clipboard()

# %%
composers_alive = composers_alive.drop_duplicates()

# %%
composers_alive = composers_alive.groupby('Verstorben').count()
composers_alive
# Out:
#             Komponist_ber
# Verstorben
# Tot                    48
# lebt                   18

# %%
composers_alive.Komponist_ber.sum()
# Out:
# 66

# %%
composers_alive['%']= composers_alive.Komponist_ber.apply(lambda x: round(x / composers_alive.Komponist_ber.sum() * 100))

# %%
composers_alive
# Out:
#             Komponist_ber     %
# Verstorben
# Tot                    48  73.0
# lebt                   18  27.0

# %% [markdown]
# #### Lebensdaten der Komponisten
#
# Die Grafik zeigt die Lebensdaten der 66 Komponist*innen auf einen Blick.

# %%
df.columns
# Out:
# Index(['Spielstätte', 'Ort', 'Titel', 'Anzahl', 'Komponist', 'Komponist_ber',
#        'Geburtsort', 'Geschlecht', 'Geburtsjahr', 'Alter', 'Sterbedatum',
#        'Verstorben', 'Art', 'Bemerkung', 'Zauberflöte'],
#       dtype='object')

# %%
lebensdaten = df[['Komponist_ber', 'Geburtsjahr', 'Sterbedatum']]

# %%
lebensdaten = lebensdaten.drop_duplicates()

# %%
lebensdaten.Sterbedatum = lebensdaten.Sterbedatum.apply(lambda x: 2019 if x== 0 else x)

# %%
lebensdaten = lebensdaten[lebensdaten.Geburtsjahr > 0]

# %%
lebensdaten.rename(columns={'Sterbedatum': 'Sterbejahr'}, inplace=True)

# %%
lebensdaten = lebensdaten.sort_values('Geburtsjahr')

# %%
lebensdaten["type"] = "range"

# %%
lebensdaten.sample()
# Out:
#            Komponist_ber  Geburtsjahr  Sterbejahr   type
# 3  Johann Christian Bach         1735        1782  range

# %%
lebensdaten.to_json('lebensdaten.json', orient='records')

# %% [markdown]
# #### Meistegspielte Komponisten

# %%
composers_count = pd.pivot_table(composers, index=['Komponist_ber'], aggfunc='count').sort_values(by='Anzahl', ascending=False)

# %%
composers_count.head(10)
# Out:
#                          Anzahl  Titel
# Komponist_ber
# Giuseppe Verdi               22     22
# Wolfgang Amadeus Mozart      15     15
# Richard Wagner               12     12
# Giacomo Puccini               9      9
# Jacques Offenbach             7      7
# Engelbert Humperdinck         7      7
# Richard Strauss               5      5
# Franz Lehár                   4      4
# Leonard Bernstein             3      3
# Antonín Dvořák                3      3

# %%
len(set(df[df.Komponist_ber == 'Giuseppe Verdi'].Titel))
# Out:
# 13

# %%
set(df[df.Komponist_ber == 'Giuseppe Verdi'].Titel)
# Out:
# {'Aida',
#  'Die sizilianische Vesper',
#  'Don Carlo',
#  'Falstaff',
#  'Jérusalem',
#  'La Traviata',
#  'La forza del destino',
#  'Luisa Miller',
#  'Nabucco',
#  'Otello',
#  'Rigoletto',
#  'Simon Boccanegra',
#  'Viva Verdi'}

# %% [markdown]
# #### Meistgespielte anhand Anzahl der Aufführungen

# %%
composers_count = pd.pivot_table(composers, index=['Komponist_ber'], aggfunc='sum').sort_values(by='Anzahl', ascending=False)

# %%
composers_count.head(10)
# Out:
#                          Anzahl
# Komponist_ber
# Giuseppe Verdi              143
# Wolfgang Amadeus Mozart     118
# Richard Wagner               68
# Jacques Offenbach            59
# Giacomo Puccini              43
# Engelbert Humperdinck        42
# Leonard Bernstein            32
# Richard Strauss              30
# Franz Lehár                  29
# Gioachino Rossini            28

# %%
composers_count.tail()
# Out:
#                       Anzahl
# Komponist_ber
# Frank Engel                1
# Dirk Heidicke              1
# Fons Merkies               1
# Wilfried Hiller            1
# Friedrich von Flotow       1

# %% [markdown]
# #### Alter der Komponisten

# %%
composers_age = df[['Komponist_ber', 'Alter']]
composer_age = composers_age[composers_age.Alter.notnull()]
composers_age.Alter.median()
# Out:
# 181.0

# %%
composers_age.Alter.mean()
# Out:
# 175.0817610062893

# %%
composers_age.Alter.mode()
# Out:
# 0    206
# dtype: int64

# %%
composers_age.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0213d3d208>]],
#       dtype=object)

# %%
composers_age.Alter.max()
# Out:
# 452

# %%
composers_age = composers_age.sort_values(by='Alter', ascending=False)

# %%
composers_age = composers_age.drop_duplicates()

# %%
composers_age.head()
# Out:
#               Komponist_ber  Alter
# 11       Claudio Monteverdi    452
# 152           Henry Purcell    360
# 158  Georg Friedrich Händel    334
# 3     Johann Christian Bach    284
# 88          Antonio Salieri    269

# %%
composers_age.tail()
# Out:
#      Komponist_ber  Alter
# 134  Anno Schreier     40
# 150  Moritz Anthes     39
# 79    Nuñez Hierro     39
# 58   Leonard Evers     34
# 114  Dirk Heidicke      0

# %% [markdown]
# #### Alter vs Anzahl der Aufführungen

# %%
age_vs_anzahl = df[['Komponist_ber', 'Alter', 'Anzahl', 'Verstorben']]

# %%
age_vs_anzahl = age_vs_anzahl.pivot_table(values=['Anzahl', 'Alter', 'Verstorben'], index='Komponist_ber', aggfunc={'Anzahl': 'sum', 'Alter': 'min', 'Verstorben': 'min'})

# %%
age_vs_anzahl.sort_values(by='Anzahl', ascending=False).head()
# Out:
#                          Alter  Anzahl Verstorben
# Komponist_ber
# Giuseppe Verdi             206     143        Tot
# Wolfgang Amadeus Mozart    263     118        Tot
# Richard Wagner             206      68        Tot
# Jacques Offenbach          200      59        Tot
# Giacomo Puccini            161      43        Tot

# %%
age_vs_anzahl.to_clipboard()

# %%
age_vs_anzahl.Verstorben = age_vs_anzahl.Verstorben.apply(lambda x: 1 if x == 'Tot' else 0)

# %%
age_vs_anzahl.sample()
# Out:
#                Alter  Anzahl  Verstorben
# Komponist_ber
# Jake Heggie       58       6           0

# %%
age_vs_anzahl.plot.scatter(x='Alter', y='Anzahl', c='Verstorben', colormap='jet')
plt.savefig('./img/age_vs_anzahl_scatter.png')

# %%
age_vs_anzahl.to_csv('./csv/age_vs_anzahl.csv')

# %% [markdown]
# ### Häuser

# %%
df.Ort.value_counts()
# Out:
# Düsseldorf/Duisburg        38
# Köln                       20
# Essen                      16
# Bonn                       13
# Krefeld/Mönchengladbach    12
# Gelsenkirchen              12
# Wuppertal                  10
# Dortmund                    9
# Hagen                       9
# Aachen                      8
# Bielefeld                   7
# Herford                     4
# Minden                      1
# Name: Ort, dtype: int64

# %%
# Out:
# <bound method DataFrame.pivot of           Geburtsort  Sterbedatum Geschlecht  \
# 0                NaN            0   männlich
# 1                NaN            0   männlich
# 2                NaN            0   männlich
# 3            Cremona            0   männlich
# 4        Westminster         1695   männlich
# 5      Halle (Saale)         1759   männlich
# 6      Halle (Saale)         1759   männlich
# 7      Halle (Saale)         1759   männlich
# 8            Leipzig         1782   männlich
# 9            Legnago         1825   männlich
# 10          Salzburg         1791   männlich
# 11          Salzburg         1791   männlich
# 12          Salzburg         1791   männlich
# 13          Salzburg         1791   männlich
# 14          Salzburg         1791   männlich
# 15          Salzburg         1791   männlich
# 16          Salzburg         1791   männlich
# 17          Salzburg         1791   männlich
# 18          Salzburg         1791   männlich
# 19          Salzburg         1791   männlich
# 20          Salzburg         1791   männlich
# 21          Salzburg         1791   männlich
# 22          Salzburg         1791   männlich
# 23          Salzburg         1791   männlich
# 24          Salzburg         1791   männlich
# 25              Bonn         1827   männlich
# 26             Eutin         1826   männlich
# 27             Eutin         1826   männlich
# 28             Eutin         1826   männlich
# 29             Eutin         1826   männlich
# ..               ...          ...        ...
# 140           Dessau         1950   männlich
# 141              NaN            0        NaN
# 144       Le Roncole         1901   männlich
# 145        Lowestoft         1976   männlich
# 146         Lawrence         1990   männlich
# 147         Lawrence         1990   männlich
# 148         Lawrence         1990   männlich
# 149             Wien         2011   männlich
# 150              NaN            0        NaN
# 151     Buenos Aires         2008   männlich
# 154           Berlin            0   männlich
# 155        Baltimore            0   männlich
# 156       Weißenhorn            0   männlich
# 161              NaN            0        NaN
# 169          Glasgow         2018   männlich
# 170          Glasgow         2018   männlich
# 172       Long Beach            0   männlich
# 174          Mailand            0   männlich
# 175              NaN            0        NaN
# 176   Greater London            0   männlich
# 202   Greater London            0   männlich
# 203  West Palm Beach            0   männlich
# 204          Zaandam            0   männlich
# 207              NaN            0        NaN
# 209              NaN            0        NaN
# 210              NaN            0        NaN
# 211              NaN            0        NaN
# 212           Aachen            0   männlich
# 217              NaN            0        NaN
# 220              NaN            0        NaN
#
#                                Spielstätte  Veranstalter  \
# 0                   Deutsche Oper am Rhein  Stadttheater
# 1    Musiktheater im Revier, Gelsenkirchen  Stadttheater
# 2                          Theater Herford  Stadttheater
# 3                            Theater Hagen  Stadttheater
# 4                            Theater Hagen  Stadttheater
# 5                           Theater Aachen  Stadttheater
# 6             Theater/Oper/Schauspiel Bonn  Stadttheater
# 7                   Deutsche Oper am Rhein  Stadttheater
# 8                        Theater Bielefeld  Stadttheater
# 9                                Oper Köln  Stadttheater
# 10                  Deutsche Oper am Rhein  Stadttheater
# 15                 Bielefeld  wiederaufnahmen
# 16       Düsseldorf/Duisburg  wiederaufnahmen
# 17       Düsseldorf/Duisburg  wiederaufnahmen
# 18       Düsseldorf/Duisburg  wiederaufnahmen
# 19       Düsseldorf/Duisburg  wiederaufnahmen
# 20                     Essen        premieren
# 21                     Essen  wiederaufnahmen
# 22                     Essen  wiederaufnahmen
# 23                      Köln        premieren
# 24   Krefeld/Mönchengladbach        premieren
# 25                 Wuppertal        premieren
# 26                      Köln  wiederaufnahmen
# 27                     Essen        premieren
# 28                     Essen        premieren
# 29                     Essen        premieren
# ..                       ...              ...
# 140                     Köln        premieren
# 141            Gelsenkirchen        premieren
# 144                Wuppertal        premieren
# 145                     Köln        premieren
# 146            Gelsenkirchen        premieren
# 147                   Aachen        premieren
# 148                 Dortmund        premieren
# 149                     Köln  wiederaufnahmen
# 150                   Aachen        premieren
# 151                     Köln        premieren
# 154                    Essen        premieren
# 155                 Dortmund        premieren
# 156                     Köln  wiederaufnahmen
# 161  Krefeld/Mönchengladbach        premieren
# 169                 Dortmund        premieren
# 170      Düsseldorf/Duisburg  wiederaufnahmen
# 172      Düsseldorf/Duisburg        premieren
# 174                 Dortmund        premieren
# 175  Krefeld/Mönchengladbach        premieren
# 176                     Bonn        premieren
# 202                Wuppertal        premieren
# 203                Bielefeld        premieren
# 204                 Dortmund        premieren
# 207                     Bonn        premieren
# 209      Düsseldorf/Duisburg  wiederaufnahmen
# 210                     Köln        premieren
# 211            Gelsenkirchen  wiederaufnahmen
# 212      Düsseldorf/Duisburg        premieren
# 217                Wuppertal        premieren
# 220      Düsseldorf/Duisburg        sonstiges
#
#                                                  Titel  \
# 0    Petruschka / L'Enfant et les Sortilèges (Haus ...
# 1                                       Und jetzt alle
# 2                     Cavalleria rusticana / Pagliacci
# 3             Paul Abraham - Operettenkönig von Berlin
# 4                Combattimento di Trancredi e Clorinda
# 5                      Wassermusik und Dido and Aeneas
# 6                Il trionfo del Tempo e del Disinganno
# 7                                               Xerxes
# 8                                               Xerxes
# 9                                               Amadis
# 10                                La scuola de’ gelosi
# 11                                     Die Zauberflöte
# 12                                     Die Zauberflöte
# 13                                        Don Giovanni
# 14                                      Cosi fan tutte
# 15                                     Die Zauberflöte
# 16                                     Die Zauberflöte
# 17                                  Le nozze di Figaro
# 18                       Die Entführung aus dem Serail
# 19                                        Don Giovanni
# 20                                      Cosi fan tutte
# 21                                     Die Zauberflöte
# 22                                        Don Giovanni
# 23                          Die Zauberflöte für Kinder
# 24                                     Die Zauberflöte
# 25                             Die Hochzeit des Figaro
# 26                                             Fidelio
# 27                                      Der Freischütz
# 28                                      Der Freischütz
# 29                                      Der Freischütz
# ..                                                 ...
# 140                                       Street Scene
# 141                                          Mahagonny
# 144                                 Play Europeras 1&2
# 145                                       Peter Grimes
# 146                                               Mass
# 147                  Troubel in Tahiti / A Quiet Place
# 148                                    West Side Story
# 149                               Adam Schaf hat Angst
# 150                          Elegie für junge Liebende
# 151                                       Mare Nostrum
# 154                                              Medea
# 155                                           Echnaton
# 156                                               Ijob
# 161                                 Der goldene Drache
# 169                         Wo die wilden Kerle wohnen
# 211                                      Thomas Rimes       4         1976
# 212                                     Anno Schreier       4         1979
# 217                                      Nuñez Hierro       8         1980
# 220                                     Leonard Evers       7         1985
#
#      Alter Verstorben Oper                                          Bemerkung
# 0        0       Lebt   Ja                                   Zwei Komponisten
# 1        0       Lebt   Ja                                   Zwei Komponisten
# 2        0        Tot   Ja                                   Zwei Komponisten
# 3        0       Lebt   Ja        Geburtsdatum? Premiere oder Wiederaufnahme?
# 4      452        Tot   Ja                                                NaN
# 5      360        Tot   Ja                                                NaN
# 6      334        Tot   Ja                                                NaN
# 7      334        Tot   Ja                                                NaN
# 8      334        Tot   Ja                                                NaN
# 9      284        Tot   Ja                                                NaN
# 10     269        Tot   Ja                                                NaN
# 11     263        Tot   Ja  Ist Aufführung: Zauberflöte für Kinder - Premi...
# 12     263        Tot   Ja                                                NaN
# 13     263        Tot   Ja                                                NaN
# 14     263        Tot   Ja                                                NaN
# 15     263        Tot   Ja                                                NaN
# 16     263        Tot   Ja                                                NaN
# 17     263        Tot   Ja                                                NaN
# 18     263        Tot   Ja                                                NaN
# 19     263        Tot   Ja                                                NaN
# 20     263        Tot   Ja                                                NaN
# 21     263        Tot   Ja                                                NaN
# 22     263        Tot   Ja                                                NaN
# 23     263        Tot   Ja                                                NaN
# 24     263        Tot   Ja                                                NaN
# 25     263        Tot   Ja                                                NaN
# 26     249        Tot   Ja                                                NaN
# 27     233        Tot   Ja                                                NaN
# 28     233        Tot   Ja                                                NaN
# 29     233        Tot   Ja                                                NaN
# ..     ...        ...  ...                                                ...
# 140    119        Tot   Ja                                                NaN
# 141    119        Tot   Ja                                                NaN
# 144    107        Tot   Ja                                                NaN
# 145    106        Tot   Ja                                                NaN
# 146    101        Tot   Ja                                                NaN
# 147    101        Tot   Ja                                                NaN
# 148    101        Tot   Ja                                                NaN
# 149     97        Tot   Ja                                                NaN
# 150     93        Tot   Ja                                                NaN
# 151     88        Tot   Ja                                                NaN
# 154     83       Lebt   Ja                                                NaN
# 155     82       Lebt   Ja                                                NaN
# 156     78       Lebt   Ja                                                NaN
# 161     75       Lebt   Ja                                                NaN
# 169     67        Tot   Ja                                                NaN
# 170     67        Tot   Ja                                                NaN
# 172     66       Lebt   Ja                                                NaN
# 174     63       Lebt   Ja                                                NaN
# 175     63       Lebt   Ja                                                NaN
# 176     60       Lebt   Ja                                                NaN
# 202     60       Lebt   Ja                                                NaN
# 203     58       Lebt   Ja                                                NaN
# 204     53       Lebt   Ja                                                NaN
# 207     50       Lebt   Ja                                                NaN
# 209     50       Lebt   Ja                                                NaN
# 210     44       Lebt   Ja                                                NaN
# 211     43       Lebt   Ja                                                NaN
# 212     40       Lebt   Ja                                                NaN
# 217     39       Lebt   Ja                                                NaN
# 220     34       Lebt   Ja                     Premiere oder Wiederaufnahme?
#
# [161 rows x 15 columns]>

# %%
df.groupby('Komponist_ber').count().sort_values(by='Spielstätte', ascending=False).head(10)
# Out:
#                          Geburtsort  Sterbedatum  Geschlecht  Spielstätte  \
# Komponist_ber
# Giuseppe Verdi                   22           22          22           22
# Wolfgang Amadeus Mozart          15           15          15           15
# Richard Wagner                   11           11          11           11
# Giacomo Puccini                   8            9           8            9
# Engelbert Humperdinck             7            7           7            7
# Jacques Offenbach                 6            7           6            7
# Richard Strauss                   5            5           5            5
# Franz Lehár                       4            4           4            4
# Carl Maria von Weber              4            4           4            4
# Georg Friedrich Händel            3            3           3            3
#
#                          Veranstalter  Ort  Art  Titel  Anzahl  Geburtsjahr  \
# Komponist_ber
# Giuseppe Verdi                     22   22   22     22      22           22
# Wolfgang Amadeus Mozart            15   15   15     15      15           15
# Richard Wagner                     11   11   11     11      11           11
# Giacomo Puccini                     9    9    9      9       9            9
# Engelbert Humperdinck               7    7    7      7       7            7
# Jacques Offenbach                   7    7    7      7       7            7
# Richard Strauss                     5    5    5      5       5            5
# Franz Lehár                         4    4    4      4       4            4
# Carl Maria von Weber                4    4    4      4       4            4
# Georg Friedrich Händel              3    3    3      3       3            3
#
#                          Alter  Verstorben  Oper  Bemerkung
# Komponist_ber
# Giuseppe Verdi              22          22    22          0
# Wolfgang Amadeus Mozart     15          15    15          1
# Richard Wagner              11          11    11          0
# Giacomo Puccini              9           9     9          1
# Engelbert Humperdinck        7           7     7          0
# Jacques Offenbach            7           7     7          1
# Richard Strauss              5           5     5          0
# Franz Lehár                  4           4     4          1
# Carl Maria von Weber         4           4     4          0
# Georg Friedrich Händel       3           3     3          0

# %%
 df[df.Geschlecht == 'weiblich']
# Out:
#             Spielstätte        Ort                 Titel  Anzahl Komponist  \
# 117  Wuppertaler Bühnen  Wuppertal  Kleines Stück Himmel       8       NaN
#
#     Komponist_ber Geburtsort Geschlecht  Geburtsjahr  Alter  Sterbedatum  \
# 117  Nuñez Hierro      Cádiz   weiblich         1980     39            0
#
#     Verstorben        Art Bemerkung
# 117       lebt  premieren       NaN

# %%
geburtsorte = df[['Komponist_ber', 'Geburtsort']]

# %%
geburtsorte = geburtsorte.drop_duplicates()

# %%
geburtsorte.to_csv('geburtsorte.csv')

# %% [markdown]
# ### Spielstätten

# %%
df.columns
# Out:
# Index(['Spielstätte', 'Ort', 'Titel', 'Anzahl', 'Komponist', 'Komponist_ber',
#        'Geburtsort', 'Geschlecht', 'Geburtsjahr', 'Alter', 'Sterbedatum',
#        'Verstorben', 'Art', 'Bemerkung'],
#       dtype='object')

# %%
df.groupby('Spielstätte').sum().sort_values(by='Anzahl', ascending= False)
# Out:
#                                        Anzahl  Geburtsjahr  Alter  Sterbedatum
# Spielstätte
# Deutsche Oper am Rhein                    218        69743   6979        64192
# Oper Köln                                 150        37128   3252        34424
# Theater/Oper/Schauspiel Bonn              105        23867   2380        20654
# Theater Krefeld Mönchengladbach            82        22228   2000        18987
# Musiktheater im Revier, Gelsenkirchen      75        22528   1700        19180
# Theater Hagen                              74        15975   2196        16599
# Theater und Philharmoie Essen              74        29180   3124        28181
# Theater Aachen                             68        14548   1604        15134
# Oper, Ballett und Junge Oper Dortmund      67        17062   1109        11649
# Wuppertaler Bühnen                         55        18749   1441        15333
# Theater Bielefeld                          46        12803   1330        11210
# Stadttheater Minden                         6         1813    206         1883
# Theater Herford                             4         5540    517         5755

# %%
# Out:
# 69187.20497623291
